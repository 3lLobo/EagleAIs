# %%
from ultralytics import YOLO

# Load a model
# model = YOLO("yolov8n.yaml")  # build a new model from scratch
model = YOLO("yolov8n.pt")  # load a pretrained model (recommended for training)

# %%
# Use the model
epochs = 311
data_path = '/home/wolf/worqspace/EagleEyez/data/potholes_labels_yolo_220116/yolo220116.yaml'
results_train = model.train(data=data_path, epochs=epochs)  # train the model
results_val = model.val()  # evaluate model performance on the validation set
success = model.export(format="onnx")  # export the model to ONNX format
# Out:
# Ultralytics YOLOv8.0.9 🚀 Python-3.10.6 torch-1.13.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3080 Laptop GPU, 8192MiB)
# ...

# %%
test_path = '/home/wolf/worqspace/EagleEyez/data/png/s2/0029.png'
results_test = model(test_path)  # predict on an image

# %%
predictions = model.predict('/home/wolf/worqspace/EagleEyez/data/png/s2/0111.png', save=True)
# Out:
# Ultralytics YOLOv8.0.9 🚀 Python-3.10.6 torch-1.13.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3080 Laptop GPU, 8192MiB)
# Fusing layers...
# Model summary: 168 layers, 3006233 parameters, 0 gradients
# Results saved to /home/wolf/worqspace/EagleEyez/runs/detect/predict

# %%
import os
from PIL import Image

img_dir = '/home/wolf/worqspace/EagleEyez/data/png/s2/'
images = []
#  Loop over all the images
for img in os.listdir(img_dir):
  # Append the full path of the image to the list
  if img.endswith('.png'):
    image = Image.open(img_dir + img)
    images.append(image)

model.predict(images, save=True)
# Out:
# Ultralytics YOLOv8.0.9 🚀 Python-3.10.6 torch-1.13.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3080 Laptop GPU, 8192MiB)
# Fusing layers...
# Model summary: 168 layers, 3006233 parameters, 0 gradients
# Results saved to /home/wolf/worqspace/EagleEyez/runs/detect/predict3
# [Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Results'> instance
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([4, 6])
#  dtype: torch.float32
#  original size: (1080, 1920),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Results'> instance
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([3, 6])
#  dtype: torch.float32
#  original size: (1080, 1920),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Results'> instance
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
# ...
